# %% [markdown]
# ## Expore chat in PydatnicAI

# %%
from pydantic_ai import Agent 
from dotenv import load_dotenv
from constants import MODEL_SMALL, MODEL_MEDIUM, MODEL,LARGE

# Overrides eventual chaching of environment variables by .env file
load_dotenv(override=True)

Agent(
    model=MODEL_SMALL,
    system_prompt="Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.",
)

result = await Agent.run("Why is it not sunny in göteborg?")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pydantic_ai import Agent
#       2 from dotenv import load_dotenv
# ----> 3 from constants import MODEL_SMALL, MODEL_MEDIUM, MODEL,LARGE
#       4
#       5 # Overrides eventual chaching of environment variables by .env file
#       6 load_dotenv(override=True)
#
# ImportError: cannot import name 'MODEL' from 'constants' (/Users/leolindqvistkrohnert/mlops-1/0_6_pydanticai_fastapi_chatbot/constants.py)

# %%
result.output
