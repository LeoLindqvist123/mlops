# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "Tell me a math joke"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output='Why do programmers prefer dark mode? \n\nBecause light attracts bugs! 🐛💻')

# %%
print(result.output)
# Out:
# Why do programmers prefer dark mode?
#
# Because light attracts bugs! 🐛💻

# %%
result = await agent.run("What is the weather in stockholm today?")
print(result.output)
# Out:
# Hmm, let me check... Oh wait, I’m not quite in Stockholm right now, are I? 😊 But if we were, what would you say about the *weather*? Because I’m totally convinced you’re about to have a *Code Breaker Day*! *Code *beep*, *cloud* *rises*, let’s debug this! Is it sunny or… confusing? 🕵️‍♂️⌚

# %% [markdown]
# ## Check messeages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 7, 48852, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 7, 48864, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 7, 49126, tzinfo=datetime.timezone.utc), run_id='019d6753-ee87-76b5-ae78-9142ae9641bf'),
#  ModelResponse(parts=[TextPart(content='Hmm, let me check... Oh wait, I’m not quite in Stockholm right now, are I? 😊 But if we were, what would you say about the *weather*? Because I’m totally convinced you’re about to have a *Code Breaker Day*! *Code *beep*, *cloud* *rises*, let’s debug this! Is it sunny or… confusing? 🕵️\u200d♂️⌚')], usage=RequestUsage(input_tokens=43, output_tokens=95, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 7, 756315, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 7, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555047-NXq4rl2RIW9SAsTPCk6U', finish_reason='stop', run_id='019d6753-ee87-76b5-ae78-9142ae9641bf')]

# %%
len(messages)
# Out:
# 2

# %% [markdown]
# note:
#
# - systemprompt and user prompt
# - timestamp
# - run_id
# - type is modelrequest

# %%
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 7, 48852, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 7, 48864, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 7, 49126, tzinfo=datetime.timezone.utc), run_id='019d6753-ee87-76b5-ae78-9142ae9641bf')

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content='Hmm, let me check... Oh wait, I’m not quite in Stockholm right now, are I? 😊 But if we were, what would you say about the *weather*? Because I’m totally convinced you’re about to have a *Code Breaker Day*! *Code *beep*, *cloud* *rises*, let’s debug this! Is it sunny or… confusing? 🕵️\u200d♂️⌚')], usage=RequestUsage(input_tokens=43, output_tokens=95, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 7, 756315, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 7, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555047-NXq4rl2RIW9SAsTPCk6U', finish_reason='stop', run_id='019d6753-ee87-76b5-ae78-9142ae9641bf')

# %% [markdown]
# - textpart
# - metadata(tokens, model, provider)

# %% [markdown]
# ## Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=43, output_tokens=95, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_prompt ="What is the weather in stockholm today?"

len(user_prompt.split())
# Out:
# 7

# %%
system_prompt = agent._system_prompts[0]
system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'
